# %%
import polars
import hvplot.polars

import holoviews as hv
import utils

from polars import col
# Out:
# %opts magic unavailable (pyparsing cannot be imported)
# %compositor magic unavailable (pyparsing cannot be imported)
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="a94a85bb-715f-4714-a44c-3ba2b83950aa" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
amd = utils.load_asset_data("AMD").tail(50)
amd.head()
# Out:
# shape: (5, 9)
# ┌────────────┬────────────┬────────────┬───────────┬───┬──────────┬───────────┬────────┬───────────┐
# │ Date       ┆ Open       ┆ High       ┆ Low       ┆ … ┆ Volume   ┆ Dividends ┆ Stock  ┆ Time Zone │
# │ ---        ┆ ---        ┆ ---        ┆ ---       ┆   ┆ ---      ┆ ---       ┆ Splits ┆ ---       │
# │ date       ┆ f64        ┆ f64        ┆ f64       ┆   ┆ i64      ┆ f64       ┆ ---    ┆ str       │
# │            ┆            ┆            ┆           ┆   ┆          ┆           ┆ f64    ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪══════════╪═══════════╪════════╪═══════════╡
# │ 2024-05-29 ┆ 167.460007 ┆ 168.479996 ┆ 162.91000 ┆ … ┆ 56537500 ┆ 0.0       ┆ 0.0    ┆ EDT       │
# │            ┆            ┆            ┆ 4         ┆   ┆          ┆           ┆        ┆           │
# │ 2024-05-30 ┆ 167.899994 ┆ 168.75     ┆ 163.80000 ┆ … ┆ 46479900 ┆ 0.0       ┆ 0.0    ┆ EDT       │
# ...

# %%
usd = utils.load_asset_data("USD")
usd.head()
# Out:
# shape: (5, 9)
# ┌────────────┬───────────┬───────────┬───────────┬───┬────────┬───────────┬────────┬───────────┐
# │ Date       ┆ Open      ┆ High      ┆ Low       ┆ … ┆ Volume ┆ Dividends ┆ Stock  ┆ Time Zone │
# │ ---        ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---    ┆ ---       ┆ Splits ┆ ---       │
# │ date       ┆ f64       ┆ f64       ┆ f64       ┆   ┆ i64    ┆ f64       ┆ ---    ┆ str       │
# │            ┆           ┆           ┆           ┆   ┆        ┆           ┆ f64    ┆           │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪════════╪═══════════╪════════╪═══════════╡
# │ 1975-01-02 ┆ 97.709999 ┆ 97.709999 ┆ 97.709999 ┆ … ┆ 0      ┆ 0.0       ┆ 0.0    ┆ EST       │
# │ 1975-01-03 ┆ 97.169998 ┆ 97.169998 ┆ 97.169998 ┆ … ┆ 0      ┆ 0.0       ┆ 0.0    ┆ EST       │
# │ 1975-01-06 ┆ 96.620003 ┆ 96.620003 ┆ 96.620003 ┆ … ┆ 0      ┆ 0.0       ┆ 0.0    ┆ EST       │
# ...

# %%
import indicatory.currency as cur
import indicatory.names as names
from datetime import date

# %%
rcs = cur.relative_currency_strength(amd, usd)
rcs.head()
# Out:
# shape: (5, 11)
# ┌────────────┬────────────┬────────────┬───────────┬───┬────────┬───────────┬──────────┬───────────┐
# │ Date       ┆ Open       ┆ High       ┆ Low       ┆ … ┆ Stock  ┆ Time Zone ┆ RSC Open ┆ RCS Close │
# │ ---        ┆ ---        ┆ ---        ┆ ---       ┆   ┆ Splits ┆ ---       ┆ ---      ┆ ---       │
# │ date       ┆ f64        ┆ f64        ┆ f64       ┆   ┆ ---    ┆ str       ┆ f64      ┆ f64       │
# │            ┆            ┆            ┆           ┆   ┆ f64    ┆           ┆          ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪════════╪═══════════╪══════════╪═══════════╡
# │ 2024-05-29 ┆ 167.460007 ┆ 168.479996 ┆ 162.91000 ┆ … ┆ 0.0    ┆ EDT       ┆ 1.600344 ┆ 1.571265  │
# │            ┆            ┆            ┆ 4         ┆   ┆        ┆           ┆          ┆           │
# │ 2024-05-30 ┆ 167.899994 ┆ 168.75     ┆ 163.80000 ┆ … ┆ 0.0    ┆ EDT       ┆ 1.59707  ┆ 1.592341  │
# ...

# %%
ohlc = utils.ohlc_plot(amd)
rcs_plot = utils.lines_plot(rcs, value_fields=[names.rcs_open(), names.rcs_close()], color=["orange", "lightgreen"])

hv.Layout(ohlc + rcs_plot).cols(1)
# Out:
# :Layout
#    .Overlay.I   :Overlay
#       .Segments.I   :Segments   [Date,Low,Date,High]   (Open,High,Low,Close,lbound,ubound)
#       .Rectangles.I :Rectangles   [lbound,Open,ubound,Close]   (Open,High,Low,Close,lbound,ubound)
#    .NdOverlay.I :NdOverlay   [Variable]
#       :Curve   [Date]   (value)
